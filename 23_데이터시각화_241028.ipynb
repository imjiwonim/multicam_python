# %%
import matplotlib

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import matplotlib.font_manager as fm

for i in fm.fontManager.ttflist:
    if i.name.find('Gothic') != -1 : #Gulim, NanumGothic
        print(i.name)
# Out:
# HYGothic-Extra
# Franklin Gothic Demi
# Copperplate Gothic Light
# Yu Gothic
# Malgun Gothic
# Century Gothic
# Franklin Gothic Heavy
# Century Gothic
# Yu Gothic
# Franklin Gothic Medium Cond
# Malgun Gothic
# Franklin Gothic Demi
# MS Gothic
# Malgun Gothic
# Franklin Gothic Demi Cond
# HYGothic-Medium
# Century Gothic
# Franklin Gothic Medium
# Franklin Gothic Medium
# Copperplate Gothic Bold
# Yu Gothic
# Franklin Gothic Book
# Franklin Gothic Heavy
# Franklin Gothic Book
# Century Gothic
# Showcard Gothic
# Yu Gothic

# %%
from matplotlib import rcParams
rcParams['font.family'] = 'Malgun Gothic' #matplotlib에 사용할 기본폰트를 지정
rcParams['axes.unicode_minus'] = False

#맥에서는 AppleGothic, NanumGothic 등을 사용

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0,10, 100)
y = np.sin(x)

plt.plot(x,y)
plt.title('사인 곡선')
plt.xlabel('시간')
plt.ylabel('진폭')
plt.show()

# %% [markdown]
# # 1. 데이터 시각화의 중요성

# %% [markdown]
# ![Image20241029140817.png](attachment:57d171b3-0f05-4c46-b9d4-1ac60027c306.png)

# %%
import seaborn as sns
anscombe = sns.load_dataset('anscombe')
anscombe
# Out:
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68
# 11      II  10.0   9.14
# 12      II   8.0   8.14
# 13      II  13.0   8.74
# 14      II   9.0   8.77
# 15      II  11.0   9.26
# 16      II  14.0   8.10
# 17      II   6.0   6.13
# 18      II   4.0   3.10
# 19      II  12.0   9.13
# 20      II   7.0   7.26
# 21      II   5.0   4.74
# 22     III  10.0   7.46
# 23     III   8.0   6.77
# 24     III  13.0  12.74
# 25     III   9.0   7.11
# 26     III  11.0   7.81
# 27     III  14.0   8.84
# 28     III   6.0   6.08
# 29     III   4.0   5.39
# 30     III  12.0   8.15
# 31     III   7.0   6.42
# 32     III   5.0   5.73
# 33      IV   8.0   6.58
# 34      IV   8.0   5.76
# 35      IV   8.0   7.71
# 36      IV   8.0   8.84
# ...

# %%
anscombe['dataset'].unique()
# Out:
# array(['I', 'II', 'III', 'IV'], dtype=object)

# %% [markdown]
# # 2. matplotlib 라이브러리

# %%
import matplotlib.pyplot as plt
# plt.plot()

# %%
d1 = anscombe[anscombe['dataset'] == 'I']
d2 = anscombe[anscombe['dataset'] == 'II']
d3 = anscombe[anscombe['dataset'] == 'III']
d4 = anscombe[anscombe['dataset'] == 'IV']

# %%
d1.shape, d2.shape, d3.shape, d4.shape
# Out:
# ((11, 3), (11, 3), (11, 3), (11, 3))

# %%
plt.plot(d1['x'], d1['y'], 'o')
plt.show()

# %%
plt.plot(d2['x'],d2['y'])
plt.show()

# %%
# 차트를 한 영역 안에 비교할 수 있도록 모아놓는 기능
fig = plt.figure()                   # fig :  그래프를 그릴 하나의 큰 판
axes1 = fig.add_subplot(2,2,1)       # axes1 : 왼쪽 -> 오른쪽 순으로 (X by X, 순서) 괄호 안의 세번째 인자가 순서를 나타내며, '1'은 가장 왼쪽 위에 위치하게 된다.
axes2 = fig.add_subplot(2,2,2)       # axes2 : 괄호안의 첫번째, 두번째 인자는 몇개의 그래프를 그릴 건지 x축 개수와 y축 개수를 나타낸다. 샘플은 2x2의 그래프를 그리게 된다.
axes3 = fig.add_subplot(2,2,3)
axes4 = fig.add_subplot(2,2,4)
plt.show()

# %% [markdown]
# ![Image20241029143438.png](attachment:3ee25aad-b55a-4ab9-bfb6-a937d8ba7059.png)

# %% [markdown]
# ![Image20241029140820.png](attachment:afc40dcc-6d46-4c9a-a06b-de947802bfbb.png)

# %%
fig = plt.figure()
axes1 = fig.add_subplot(2,2,1)
axes2 = fig.add_subplot(2,2,2)
axes3 = fig.add_subplot(2,2,3)
axes4 = fig.add_subplot(2,2,4)

axes1.plot(d1['x'], d1['y'],'o')
axes2.plot(d2['x'], d2['y'],'o')
axes3.plot(d3['x'], d3['y'],'o')
axes4.plot(d4['x'], d4['y'],'o')

axes1.set_title('dataset 1')
axes2.set_title('dataset 2')
axes3.set_title('dataset 3')
axes4.set_title('dataset 4')

fig.suptitle('Anscombe Dataset으로 보는 데이터 시각화의 의미')
fig.set_tight_layout(True)

plt.show()

# %% [markdown]
# 데이터를 요약한 통계만으로 판단하는 것은 완전하지 않다.<br>
# 시각화를 통해 경향을 파악하는 것이 중요하다.

# %%
# 새로운 데아터셋 로드
# tips : 총 비용, 팁 비용, 성별, 흡연여부, 날짜, 시간대, 인원수

tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.color_palette()
# Out:
# [(0.12156862745098039, 0.4666666666666667, 0.7058823529411765),
#  (1.0, 0.4980392156862745, 0.054901960784313725),
#  (0.17254901960784313, 0.6274509803921569, 0.17254901960784313),
#  (0.8392156862745098, 0.15294117647058825, 0.1568627450980392),
#  (0.5803921568627451, 0.403921568627451, 0.7411764705882353),
#  (0.5490196078431373, 0.33725490196078434, 0.29411764705882354),
#  (0.8901960784313725, 0.4666666666666667, 0.7607843137254902),
#  (0.4980392156862745, 0.4980392156862745, 0.4980392156862745),
#  (0.7372549019607844, 0.7411764705882353, 0.13333333333333333),
#  (0.09019607843137255, 0.7450980392156863, 0.8117647058823529)]

# %%
base_color = sns.color_palette()[7]

# %%
point_color = sns.color_palette()[9]

# %% [markdown]
# ## 1. 일변량 그래프

# %% [markdown]
# #### 1.1 히스토그램

# %% [markdown]
# - 구간의 빈도수를 시각화하는 그래프, x의 구간을 나누며 y는 그에 대한 빈도수를 나타낸다.
# - bins 라는 parameter는 가로축 구간의 개수를 지정할 수 있다. (default = 10)
# - histogram type 에는 4가지가 있으며, 사용 방법은 아래와 같다.<br>
#       plt.hist(data = name, x = value_name, bins = value, histtype=**'bar'**) <br>
#       histtype = 'bar'(default), 'barstacked', 'step', 'stepfilled'

# %%
fig = plt.figure()
axes = fig.add_subplot(1,1,1)
axes.hist(data = tips, x = 'total_bill', bins = 20 , color = base_color, edgecolor = 'black')  #bin : 막대기
plt.show()

# %% [markdown]
# #### 1.2 Bar plot(막대그래프)

# %%
fig = plt.figure()
axes = fig.add_subplot(1,1,1)
sns.countplot(data = tips, x = 'day', color = base_color, edgecolor = 'black') 
plt.show()

# %% [markdown]
# #### 1.3 Box plot(상자그림)

# %%
fig = plt.figure()
axes = fig.add_subplot(1,1,1)
axes.boxplot(data = tips, x = 'total_bill' ) 
plt.show()

# %% [markdown]
# ## 2. 이변량 그래프

# %% [markdown]
# 시각화하고자 하는 자료가 2개 이상일 때

# %% [markdown]
# #### 2.1 Scatter plot(산점도)

# %%
fig = plt.figure()
axes = fig.add_subplot(1,1,1)
axes.scatter(tips['total_bill'], tips['tip'] )  #scatter는 두 변수의 상관관계를 표현하므로, 두 변수를 콤마로 구분해 입력한다.

plt.show()

# %% [markdown]
# #### 2.2 Box plot

# %% [markdown]
# 점 하나의 위치는 데이터 하나의 x,y의 값

# %%
fig = plt.figure()
axes = fig.add_subplot(1,1,1)
axes.boxplot(
    x = [tips[tips['sex'] == 'Female']['tip'],
        tips[tips['sex'] == 'Male']['tip']
    ],
    labels = ['Female', 'Male']
)  
plt.show()

# %% [markdown]
# ## 3. 다변량 그래프

# %%
#map()함수에 사용
colors = {"Female": "#f1a340", "Male": "#998ec3"} # 성별에 따른 색상을 지정, 여성은 주황색, 남성은 보라색 
#16진수 코드는 https://www.w3schools.com/colors/colors_picker.asp 에서 확인 가능

scatter_plot = plt.figure()
axes1 = scatter_plot.add_subplot(1, 1, 1)

axes1.scatter(data=tips,
              x='total_bill',
              y='tip',
              s=tips['size']**2*10,# size를 제곱하여 점의 크기를 키움, s는 점의 크기를 나타내는 매개변수
              c=tips['sex'].map(colors),# map()은 Series의 각 요소에 대해 특정 함수를 적용할 때 사용, c는 점의 색을 나타내는 매개변수, colors 딕셔너리에 따라 여성은 주황색, 남성은 보라색
              alpha=0.5) # alpha는 점의 투명도를 나타내는 매개변수

axes1.set_title('Colored by Sex and Sized by Size')
axes1.set_xlabel('Total Bill')
axes1.set_ylabel('Tip')

scatter_plot.suptitle('Total Bill vs Tip')

plt.show()

# %% [markdown]
# # 3. Seaborn library

# %% [markdown]
# ### 1. 일변량 그래프

# %% [markdown]
# #### 1.1 histogram plot

# %%
sns.histplot(data = tips, x = 'total_bill')
plt.show()

# %% [markdown]
# #### 1.2 kdeplot

# %%
sns.kdeplot(data = tips, x = 'total_bill')
plt.show()

# %% [markdown]
# #### 1.3 rugplot

# %%
sns.rugplot(data = tips, x = 'total_bill')
sns.histplot(data = tips, x = 'total_bill')
plt.show()

# %% [markdown]
# ▴ rugplot : rug는 데이터 위치를 x축 위에 작은 선분(rug)로 나타내어 데이터들의 위치 및 분포를 나타낸다.

# %%
palette1 = sns.color_palette('coolwarm', 10)
sns.palplot(palette1)

# %%
palette2 = sns.color_palette('coolwarm', 5)
sns.palplot(palette2)

# %%
cnt, ax = plt.subplots()
sns.countplot(data = tips, x = 'day', palette = palette2)    # palette = 'viridis'
ax.set_title('요일별 건수')
plt.show()

# %% [markdown]
# ### 2. 이변량 그래프

# %% [markdown]
# #### 2.1 scatter plot

# %%
cnt, ax = plt.subplots()
sns.scatterplot(data = tips, x = 'total_bill', y = 'tip', ax = ax , hue = 'sex', palette = 'coolwarm')
ax.set_title('correlations between total bills and tips')
plt.show()

# %% [markdown]
# #### 2.2 regplot

# %%
cnt, ax = plt.subplots()
sns.regplot(data = tips, x = 'total_bill', y = 'tip', ax = ax)
plt.show()

# %% [markdown]
# #### 2.3 joint plot

# %% [markdown]
# joint label : 산점도를 기본으로 하며, x,y축에 각 변수에 대한 히스토그램을 동시에 보여준다.

# %%
joint = sns.jointplot(data = tips, x = 'total_bill', y = 'tip')

# x축 제목추가,  y축 제목추가
joint.set_axis_labels(xlabel = 'Total Bill', ylabel = 'Tip')
joint.figure.suptitle('Joint Chart of Total bills and Tips')
plt.show()

# %% [markdown]
# #### 2.4 kdeplot

# %%
kde, ax = plt.subplots()
sns.kdeplot(data = tips, x = 'total_bill', y = 'tip', fill = True, ax = ax, ec='black', fc='white') # ec : edge color, fc : fill color
ax.set_title("KDE plot")
plt.show()

# %% [markdown]
# #### 2.5 barplot

# %%
bar, ax = plt.subplots()
sns.barplot(data = tips, x = 'time', y = 'total_bill', estimator = np.mean, ax = ax, palette = 'coolwarm')
ax.set_title("Bar Plot")
plt.show()

# %%
# error bar 파라미터 없이 출력
bar, ax = plt.subplots()
sns.barplot(data = tips, x = 'time', y = 'total_bill', errorbar = None, estimator = np.mean, ax = ax, palette = 'coolwarm')
ax.set_title("Bar Plot")
plt.show()

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# #### 2.6 boxplot

# %%
bar, ax = plt.subplots()
sns.boxplot(data = tips, x = 'time', y = 'total_bill', ax = ax, palette = 'coolwarm')
ax.set_title("Box Plot")
plt.show()

# %% [markdown]
# #### 2.7 Violin Plot

# %%
#violin plot

bar, ax = plt.subplots()
sns.violinplot(data = tips, x = 'time', y = 'total_bill', ax = ax, palette = 'coolwarm')
ax.set_title("Violin Plot")
plt.show()

# %%
fig = sns.pairplot(data = tips)
fig.figure.suptitle('Tips 데이터의 관계 분석')
plt.show()
